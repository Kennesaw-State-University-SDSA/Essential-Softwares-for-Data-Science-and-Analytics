# %%
## Upload the Cars.csv file into the
## Google Colab environment ##

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-32d9cb3d-a595-4a99-a704-1fff12db2c19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32d9cb3d-a595-4a99-a704-1fff12db2c19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
## Read the Cars Dataset into Google Colab ##

import pandas as pd
cars = pd.read_csv('Cars.csv')

# %%
## Explore the data structure of cars ##
print(cars.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   mpg         32 non-null     float64
#  2   cyl         32 non-null     int64
#  3   disp        32 non-null     float64
#  4   hp          32 non-null     int64
#  5   drat        32 non-null     float64
#  6   wt          32 non-null     float64
#  7   qsec        32 non-null     float64
#  8   vs          32 non-null     int64
#  9   am          32 non-null     int64
#  10  gear        32 non-null     int64
#  11  carb        32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB
# None

# %%
## Load NYC Airplanes 2013.xlsx Dataset ##
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4135a533-a052-4aba-95da-e3e7adafab24" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4135a533-a052-4aba-95da-e3e7adafab24">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
## Examine Data Structure ##
airplanes = pd.read_excel('NYC Airplanes 2013.xlsx')
print(airplanes.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3322 entries, 0 to 3321
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tailnum       3322 non-null   object
#  1   year          3252 non-null   float64
#  2   type          3322 non-null   object
#  3   manufacturer  3322 non-null   object
#  4   model         3322 non-null   object
#  5   engines       3322 non-null   int64
#  6   seats         3322 non-null   int64
#  7   speed         23 non-null     float64
#  8   engine        3322 non-null   object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 233.7+ KB
# None

# %%
## Identify Missing Values in Cars ##
print(cars.isnull().sum())
# Out:
# Unnamed: 0    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
## Identify Missing Values in Planes ##
print(airplanes.isnull().sum())
# Out:
# tailnum            0
# year              70
# type               0
# manufacturer       0
# model              0
# engines            0
# seats              0
# speed           3299
# engine             0
# dtype: int64
